# %% [markdown]
# # Create a  Class and function, and list out the items in the list
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
from class_assignment_module import SubfieldsInAI,OddEven,ElegiblityForMarriage,FindPercent,Triangle

SubfieldsInAI.sub_fields()
# Out:
#  Sub-fields in AI are:
#
#  Machine Learning
#
#  Neural Networks
#
#  Vision
#
#  Robotics
#
#  Speech Processing
#
#  Natural Language Processing

# %%
#from class_assignment_module import OddEven

number = int(input("Enter your input number"))
OddEven.check_odd_even(number)

# %%
age=int(input("Enter your age"))
gender=input("Enter your gender")
ElegiblityForMarriage.marriage_eligibility_check(age,gender)

# %%
FindPercent.get_percentage()

# %%
Triangle.calc_triangle_area()
# Out:
# enter the height of triangle 3
# enter the width of triangle 4
# height : 3.0
# width : 4.0
# Area formula : (height*width)/2
# Area of Triangle: : 6.0
# 6.0

# %%
Triangle.calc_triangle_area()

# %%
Triangle.calc_triangle_peri()
# Out:
# enter the height1 of triangle 3
# enter the height2 of triangle 4
# enter the width of triangle 5
# height1 : 3.0
# height2 : 4.0
# width : 5.0
# perimeter formula : (height1 + height2 + width)
# perimeter of Triangle: : 12.0
# 12.0

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
print("pyhton"+"progrma")
# Out:
# pyhtonprogrma
