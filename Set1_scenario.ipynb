# %%
import calendar

check = calendar.isleap(2001)
print(check)
# Out:
# False

# %%
import math

number_list = [10,24,76,23]
max_index = max(number_list)
print(max_index)
# Out:
# 76

# %%
salary=float(input("Enter your salary"))
if(salary >= 50000):
    bonus_percent=10/100
else:
    bonus_percent=0
bonus_amount=salary * bonus_percent
print(bonus_amount)
# Out:
# Enter your salary 20000
# 0.0

# %%
text = "Python is the basic programing for AI"
#print("".join(reversed(text))) 
print(text[::-1])
# Out:
# IA rof gnimargorp cisab eht si nohtyP

# %%
num_list=[1,2,3,4,5,6,7,8,9,0]
even_list=list(filter(lambda x :x%2 ==0,num_list))
print(even_list)

list_comp= [val for val in num_list if val % 2 == 0 ]
print(list_comp)
# Out:
# [2, 4, 6, 8, 0]
# [2, 4, 6, 8, 0]
