# %%
num1=10
num2=30
add=num1+num2
print("Number1 value is",num1 )
print("Number2 value is",num2 )
print("added value is",add )

print("difference value is" , num1-num2)
# Out:
# Number1 value is 10
# Number2 value is 30
# added value is 40
# difference value is -20

# %%
firstname4='bhuvana'

# %% [markdown]
# 4firstname="bhuvana" - this will throw the error

# %%
firstNum=int(input("enter firstnumber"))
# Out:
# enter firstnumber 30

# %%
secondNum=int(input("enter secondnumber"))
# Out:
# enter secondnumber 40

# %%
add2=firstNum + secondNum
print(add2)
# Out:
# 70
