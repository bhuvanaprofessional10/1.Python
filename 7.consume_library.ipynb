# %%
from helper_library import helper
#from helper_library import helper as help
#from module_name import OriginalClassName as AliasName

# %%
add=helper.addition(2,4)
print(add)
sub=helper.subraction(2,4)
print(sub)
helper.age_category()
#help.age_category() - using aliasname
helper.check_odd_even()
helper.calculate_bMI()
# Out:
# 6
# -2
# enter your age 2
# you are kid
# enter your input 2
# Your input is even number
# Enter your BMI 22
# You are Healthy . Your are in Normal Weight. Keep continue your current diet
# 'Normal weight'
